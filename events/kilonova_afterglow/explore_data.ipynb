# %%
import numpy as np
import pandas as pd
import h5py

# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    "font.size": 12,
    })

# %%
with h5py.File("./kilonova_afterglow_files/kn_afterglow_results_narrow.mat") as f:
    print(f.keys())
    flux = f["flux_mJy"][:]
    times = f["t_days"][:]
    nus = f["nu_Hz"][:]
# Out:
# <KeysViewHDF5 ['#refs#', 'F_peak_mJy', 'catalog_index', 'filenames', 'fit_params', 'flux_mJy', 'inclination_EM', 'log10_n0', 'n_cm3', 'nu_Hz', 'nu_labels', 'param_file_used', 't_days', 't_peak_days']>

# %%
plt.loglog(nus, flux[:, 0, 1000])

# %%
nus
# Out:
# array([[1.400000e+09],
#        [6.250000e+14],
#        [2.417989e+17]])

# %%
for j in range(50, 200):
    plt.loglog(times, flux[0, :, j])

plt.hlines([3.5e-3], 10, 1e4, color="black", linestyle="dashed")

# %%
hist, _, _ =plt.hist(times[np.argmax(flux[0, :, :], axis=0)])
